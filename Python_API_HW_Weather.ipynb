# %%
#import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from citipy import citipy

#output File (CSV)
output_data_file = "output_infocity.csv"

lat_range = (-80, 80)
lng_range = (-180, 180)

# %%
lat_lngs = []
cities = []

#latitute and longitude
lats = np.random.uniform(low=-100.000, high=100.000, size=1300)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1300)
lat_lngs = zip(lats, lngs)

#identify city
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    if city not in cities:
        cities.append(city)

#print 
len(cities)
# Out:
# 531

# %%
#weathermap api
api_key = "924783bda048569443e49dd6a03e5591"

#url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

#cities data
city_data = []

#print
print("Beginning Data Retrieval     ")
print("-----------------------------")

#counts
record_count = 1
set_count = 1

for i, city in enumerate(cities):
        
    #grouping
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    
    city_url = url + "&q=" + urllib.request.pathname2url(city)
#record
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)


    record_count += 1

    try:
        # parsing
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

    #append
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

#exception
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=924783bda048569443e49dd6a03e5591&q=geraldton
# Processing Record 2 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=924783bda048569443e49dd6a03e5591&q=bluff
# Processing Record 3 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=924783bda048569443e49dd6a03e5591&q=ushuaia
# Processing Record 4 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=924783bda048569443e49dd6a03e5591&q=punta%20arenas
# Processing Record 5 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=924783bda048569443e49dd6a03e5591&q=hermanus
# Processing Record 6 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=924783bda048569443e49dd6a03e5591&q=vaini
# ...

# %%
city_data_pd = pd.DataFrame(city_data)

lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

#csv data
city_data_pd.to_csv(output_data_file, index_label="City_ID")

#count
city_data_pd.count()
# Out:
# City          477
# Cloudiness    477
# Country       477
# Date          477
# Humidity      477
# Lat           477
# Lng           477
# Max Temp      477
# Wind Speed    477
# dtype: int64

# %%
#print
city_data_pd.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  pringsewu           0      ID  1539132269        84  -5.36  104.98
# 1   khatanga          88      RU  1539132084        93  71.98  102.47
# 2      kenai          90      US  1539129360        66  60.55 -151.26
# 3      pevek          12      RU  1539132029       100  69.70  170.27
# 4     padang          80      ID  1539132269       100  -0.92  100.36
#
#    Max Temp  Wind Speed
# 0     75.46        2.71
# 1     31.99       12.62
# 2     53.96       12.75
# 3     36.13        8.63
# 4     79.83        4.12

# %%
#scatterplots
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#graph design
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_infocity1.png")

#print plot
plt.show()

# %%
#scatterplot
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")
#graph
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_infocity2.png")

#print plot
plt.show()

# %%
#scatterplot
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#graph
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


plt.savefig("output_infocity3.png")

# print
plt.show()

# %%
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_infocity4.png")

#print
plt.show()
